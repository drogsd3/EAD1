# %% [markdown]
# <h3> Cálculo da Area

# %%
base = float(input("Digite a base: "))
altura = float(input("Digite a altura: "))
area = base * altura
print("A área do quadrilátero é:", area)
# Out:
# Digite a base:  4.7
# Digite a altura:  5.2
# A área do quadrilátero é: 24.44
