# %% [markdown]
# # Lista de exercícios AED1 - Parte 1

# %% [markdown]
# ### Exercício 0 - Faça um algoritmo para ler um número e mostrar se ele é par ou impar, positivo ou negativo.

# %%
numero= float(input("Digite um numero: "))
if(numero%2==0):
    print(f"O numero {numero} é par")
else:
    print(f"O numero {numero} é impar")
if(numero < 0): 
    print(f"O numero {numero} é negativo")
else:
    print(f"O numero {numero} é positivo")
# Out:
# Digite um numero:  -1
# O numero -1.0 é impar
# O numero -1.0 é negativo

# %% [markdown]
# ### Exercício 1 - Faça um Programa que peça dois números e imprima o maior deles.

# %%
primeiro = float(input("Digite o primeiro numero: "))
segundo = float(input("Digite o segundo numero: "))

if(primeiro > segundo):
    print(f"O numero {primeiro} é o maior.")
elif(primeiro == segundo):
    print("Os numeros são iguais.")
else:
    print(f"O numero {segundo} é o maior.")
# Out:
# Digite o primeiro numero:  44
# Digite o segundo numero:  44
# Os numeros são iguais.

# %% [markdown]
# ### Exercício 2 - Faça um Programa que peça um valor e mostre na tela se o valor é positivo ou negativo.

# %%
numero = float(input("Digite um numero: "))

if(numero < 0): 
    print(f"O numero {numero} é negativo")
else:
    print(f"O numero {numero} é positivo")
# Out:
# Digite um numero:  -1
# O numero -1.0 é negativo

# %% [markdown]
# ### Exercício 3 - Faça um Programa que verifique se uma letra digitada é vogal ou consoante.

# %%
vogais = ['A','E','I','O','U','a','e','i','o','u']
resultado = 0
letra = input("Digite uma letra: ")
for le in vogais:
    if(letra == le):
        resultado = True
if resultado:
    print("A letra é Vogal")
else:
    print("A letra é consoante")
# Out:
# Digite uma letra:  a
# A letra é consoante

# %% [markdown]
# ### Exercício 4 - Faça um programa para a leitura de duas notas parciais de um aluno. O programa deve calcular a média alcançada por aluno e apresentar:
# ##### a. A mensagem "Aprovado", se a média alcançada for maior ou igual a sete;
# ##### b. A mensagem "Reprovado", se a média for menor do que sete;
# ##### c. A mensagem "Aprovado com Distinção", se a média for igual a dez.

# %%
nota1 = float(input("Digite a primeira nota: "))
nota2 = float(input("Digite a segunda nota: "))
media = (nota1 + nota2)/2
print(media)
if(media == 10):
    print("Aprovado com Distinção")
elif(media >= 7):
    print("Aprovado")
else:
    print("Reprovado")
# Out:
# Digite a primeira nota:  10
# Digite a segunda nota:  10
# 10.0
# Aprovado com Distinção

# %% [markdown]
# ### Exercício 5 - Faça um programa que pergunte o preço de três produtos e informe qual produto você deve comprar, sabendo que a decisão é sempre pelo mais barato.

# %%
produto1 = float(input("Digite o preço do primeiro produto:"))
produto2 = float(input("Digite o preço do segundo produto:"))
produto3 = float(input("Digite o preço do terceiro produto:"))

if(produto1 < produto2 and produto1 < produto3):
    print(f"Você deveria comprar o produto 1 que custa: {produto1}")
elif(produto2 < produto1 and produto2 < produto3):
    print(f"Você deveria comprar o produto 2 que custa: {produto2}")
elif(produto3 < produto1 and produto3 < produto2):
    print(f"Você deveria comprar o produto 2 que custa: {produto3}")
else:
    print("Existe algum produto com o mesmo valor de outro")
# Out:
# Digite o preço do primeiro produto: 2
# Digite o preço do segundo produto: 5
# Digite o preço do terceiro produto: 10
# Você deveria comprar o produto 1 que custa: 2.0

# %% [markdown]
# ### Exercício 6 - Faça um Programa que leia três números e mostre-os em ordem decrescente.

# %% [markdown]
# n1 = float(input("Insira um número:"))
# n2 = float(input("Insira um número:"))
# n3 = float(input("Insira um número:"))
# if n1 >= n2 and n1 >= n3:
#     if n2 >= n3:
#         print(n1, n2, n3)
#     else:
#         print(n1, n3, n2)
# elif n2 >= n1 and n2 >= n3:
#     if n1 >= n3:
#         print(n2, n1, n3)
#     else:
#         print(n2, n3, n1)
# else:
#     if n1 >= n2:
#         print(n3, n1, n2)
#     else:
#         print(n3, n2, n1)

# %%
numero1 = int(input("Digite um numero: "))
numero2 = int(input("Digite um numero: "))
numero3 = int(input("Digite um numero: "))

if(numero1 > numero2) and (numero1 > numero3) and (numero2 > numero3):
    print(numero1, numero2, numero3)
elif(numero1 > numero2) and (numero1 > numero3) and (numero3 > numero2):
    print(numero1, numero3, numero2)
elif(numero2 > numero1) and (numero2 > numero3) and (numero1 > numero3):
    print(numero2, numero1, numero3)
elif(numero2 > numero1) and (numero2 > numero3) and (numero3 > numero1):
    print(numero2, numero3, numero1)
elif(numero3 > numero1) and (numero3 > numero2) and (numero1 > numero2):
    print(numero3, numero1, numero2)
else:
    print(numero3, numero2, numero1)
# Out:
# Digite um numero:  1
# Digite um numero:  2
# Digite um numero:  3
# 3 2 1

# %% [markdown]
# ### Exercício 7 - Faça um Programa que pergunte em que turno você estuda. Peça para digitar M-matutino ou V-Vespertino ou N- Noturno.
# Imprima a mensagem "Bom Dia!", "Boa Tarde!" ou "Boa Noite!" ou "Valor Inválido!", conforme o caso.

# %% [raw]
# turno = input("Digite o turno que você estuda: ").upper()
# if turno == "M":
#     print("Bom Dia!")
# elif turno == "V":
#     print("Boa Tarde!")
# elif turno == "N":
#     print("Boa noite!")
# else:
#     print("Valor Inválido")

# %% [markdown]
# ### Exercício 8 - As Organizações Tabajara resolveram dar um aumento de salário aos seus colaboradores e lhe contraram para desenvolver o programa que calculará os reajustes.
# #### a. Faça um programa que recebe o salário de um colaborador e o reajuste segundo o seguinte critério, baseado no  salário atual:
#
# #### b. salários até R$ 280,00 (incluindo) : aumento de 20%
#
# #### c. salários entre R$ 280,00 e R$ 700,00 : aumento de 15%
#
# #### d. salários entre R$ 700,00 e R$ 1500,00 : aumento de 10%
#
# #### e. salários de R$ 1500,00 em diante : aumento de 5% Após o aumento ser realizado, informe na tela:
#
# #### f. o salário antes do reajuste;
#
# #### g. o percentual de aumento aplicado;
#
# #### h. o valor do aumento;
#
# #### i. o novo salário, após o aumento.

# %%
salario_antigo = float(input("Digite o salário:"))
valor_aumento = 0
salario_novo = 0
percentual = ""

if salario_antigo <= 280:
    valor_aumento = salario_antigo * 0.2
    salario_novo = salario_antigo + valor_aumento
    percentual = "20%"
elif salario_antigo <= 700:    
    valor_aumento = salario_antigo * 0.15
    salario_novo = salario_antigo + valor_aumento
    percentual = "15"
elif salario_antigo <= 1500:
    valor_aumento = salario_antigo * 0.1
    salario_novo = salario_antigo + valor_aumento
    percentual = "10%"
else:
    valor_aumento = salario_antigo * 0.05
    salario_novo = salario_antigo + valor_aumento
    percentual = "5%"

print(f"Salário Anterior: {salario_antigo}\nPercentual: {percentual}\nValor do Aumento: {valor_aumento}\nSalario Novo: {salario_novo}")
# Out:
# Digite o salário: 1505
# Salário Anterior: 1505.0
# Percentual: 5%
# Valor do Aumento: 75.25
# Salario Novo: 1580.25

# %% [markdown]
# ### Exercício 9 - Faça um programa para o cálculo de uma folha de pagamento, sabendo que os descontos são do Imposto de Renda, que depende do salário bruto (conforme tabela abaixo) e 3% para o Sindicato e que o FGTS corresponde a 11% do Salário Bruto, mas não é descontado (é a empresa que deposita). O Salário Líquido corresponde ao Salário Bruto menos os descontos. O programa deverá pedir ao usuário o valor da sua hora e a quantidade de horas trabalhadas no mês.

# %% [markdown]
# ##### a. Desconto do IR:
#
# ##### b. Salário Bruto até 900 (inclusive) - isento
#
# ##### c. Salário Bruto até 1500 (inclusive) - desconto de 5%
#
# ##### d. Salário Bruto até 2500 (inclusive) - desconto de 10%
#
# ##### e. Salário Bruto acima de 2500 - desconto de 20% Imprima na tela as informações, dispostas conforme o exemplo
#
# ##### abaixo. No exemplo o valor da hora é 5 e a quantidade de hora é 220

# %%
ir = 0
valor_hora = float(input("Digite o valor da hora"))
horas_trabalhadas = int(input("Digite a quantidade de horas trabalhadas"))
salario_bruto = valor_hora * horas_trabalhadas
fgts = salario_bruto * 0.11
sindicato = salario_bruto * 0.03

if salario_bruto <= 900:
    print("Isento")
elif salario_bruto <= 1500:
    ir = salario_bruto * 0.05
elif salario_bruto <= 2500:
    ir = salario_bruto * 0.1
else:
    ir = salario_bruto * 0.2
total_desconto = ir + sindicato
salario_liquido = salario_bruto - total_desconto

print(f"""
Salário bruto:      R${salario_bruto:8.2f}
(-) IR :            R${ir:8.2f}
(-) Sindicato (3%): R${sindicato:8.2f}
(-) FGTS:           R${fgts:8.2f}
Total de descontos: R${total_desconto:8.2f}
Salário líquido:    R${salario_liquido:8.2f}""")
# Out:
# Digite o valor da hora 12.5
# Digite a quantidade de horas trabalhadas 220
# Salário bruto:      R$ 2750.00
# (-) IR :            R$  550.00
# (-) Sindicato (3%): R$   82.50
# (-) FGTS:           R$  302.50
# Total de descontos: R$  632.50
# Salário líquido:    R$ 2117.50

# %% [markdown]
# ### 10 - Faça um programa que lê as duas notas parciais obtidas por um aluno numa disciplina ao longo de um semestre, e calcule
# a sua média. A atribuição de conceitos obedece à tabela abaixo:

# %% [markdown]
# ##### a.   Média de Aproveitamento  Conceito
#
# ##### b.   Entre 9.0 e 10.0        A
#
# ##### c.   Entre 7.5 e 9.0         B
#
# ##### d.   Entre 6.0 e 7.5         C
#
# ##### e.   Entre 4.0 e 6.0         D
#
# ##### f.   Entre 4.0 e zero        E

# %%
nota1 = float(input("Digite a primeira nota: "))
nota2 = float(input("Digite a segunda nota: "))
media = (nota1 + nota2)/2
print(media)

if media <= 4:
    print("Seu conceito é E")
elif media <= 6:
    print("Seu conceito é D")
elif media <= 7.5:
    print("Seu conceito é C")
elif media <= 9:
    print("Seu conceito é B")
else:
    print("Seu conceito é A")
# Out:
# Digite a primeira nota:  4
# Digite a segunda nota:  4
# 4.0
# Seu conceito é E
