# %% [markdown]
# # Parte Prática
#
# ### Descrição dos Exercícios
#
# 1) Desenvolver um programa em linguagem PYTHON que leia um número inteiro e verifique se o número é divisível por 5 e por 3 ao mesmo tempo.
#
#
# 2) Desenvolva um programa em linguagem PYTHOn para calcular e mostrar o desconto no valor de uma compra (fornecido pelo usuário), de acordo com a tabela:
# VALOR                     DESCONTO
# - Até R$ 1000,00          10%
# - de R$ 1001,00 a R$5000  20%
# - Acima de R$ 5000,00     30%
#
# 3) Faça um programa em linguagem Python que calcula a quantidade de latas de tinta necessária para pintar un aposento. O algoritmo deve receber como entradas as dimensões desse aposento (largura e comprimento) e a quantidade, em litros, da lata de tinta.
# Considere ainda: **O pé-direito do aposento mede 2,80m; deverão ser pintadas apenas as paredes. O aposento tem apenas uma porta, medindo 0,80m x 2,10m. Cada litro de tinta pinta, aproximadamente, 3 metros quadrados.**

# %%
# exercicio 01
while True:
    try:
        numero = int(input("Digite um numero inteiro: "))
        break
    except:
        print("Entrada invalida\nTente novamente.")

if((numero % 5 == 0) and (numero % 3 == 0)):
    print(f"O {numero} é divisível por 5 e por 3 ")
else:
    print(f"o {numero} não é divisível por 5 e por 3")
# Out:
# O 90 é divisível por 5 e por 3

# %%
# exercicio 02
while True:
    try:
        valor_compra = float(input("Digite o valor da compra: "))
        break
    except:
        print("Entrada invalida\nTente novamente.")
        
valor_desconto = 0
valor_final = 0

if valor_compra <= 1000:
    valor_desconto = valor_compra * 0.1
elif valor_compra <= 5000:
    valor_desconto = valor_compra * 0.2
else:
    valor_desconto = valor_compra * 0.3

valor_final = valor_compra - valor_desconto
print(f"""
_______________________________________________________________
VALOR COMPRA {valor_compra:.2f} | DESCONTO {valor_desconto:.2f} | VALOR FINAL {valor_final:.2f} 
¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯""")
# Out:
# Entrada invalida
# Tente novamente.
# Entrada invalida
# Tente novamente.
#
# _______________________________________________________________
# VALOR COMPRA 3.00 | DESCONTO 0.30 | VALOR FINAL 2.70
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯

# %%
# exercicio 3
import math

PE_DIREITO = 2.8
PORTA = 0.8 * 2.1
area = 0
tinta_necessaria = 0
quantidade_lata = 0

largura = validar_entrada_float("Digite a largura do aposento: ")
comprimento = validar_entrada_float("Digite o comprimento do aposento: ")
litro_lata = validar_entrada_float("Quantidade em litros da lata: ")
area += (2 * (PE_DIREITO * largura)) + (2 * (PE_DIREITO * comprimento))
area -= PORTA
tinta_necessaria = area/3
quantidade_lata = math.ceil(tinta_necessaria/litro_lata)

print(f"Será necessário usar {quantidade_lata} lata(s) para pintar as paredes desse aposento.")
# Out:
# Entrada invalida - Digite um numero
# Tente novamente.
# Será necessário usar 4 lata(s) para pinta as paredes desse aposento.

# %%
def validar_entrada_float(mensagem):
    retorno = 0.0
    while True:
        try:
            retorno = float(input(mensagem))
            return retorno
        except:
            print("Entrada invalida - Digite um numero\nTente novamente.")
